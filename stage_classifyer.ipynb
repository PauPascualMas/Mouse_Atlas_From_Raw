# %% [markdown]
# ## Classify raw files to different directories according to embryonic stages using the experiment metadata
# ### *Takes as input the list of .fastq.gz files in the directory and the sequencing metadata from Pijuan-Sala et al. (2019)*

# %%
import pandas as pd
import os 
import re 
from os import listdir
from os.path import isfile, join

# %%
#path to where files have been downloaded
path_to_files= '/homes/users/ppascual/scratch/STAR_Align/Data/Reads/Pijuan/'

# %%
#list of files in the present directory
onlyfiles = [f for f in listdir(path_to_files
) if isfile(join(path_to_files
, f))]
onlyfiles = [k for k in onlyfiles if 'fastq.gz' in k]
onlyfiles
# Out:
# []

# %%
#importing metadata file 
met = pd.read_csv(path_to_files + 'E-MTAB-6967.sdrf.txt', sep='\t')
met
# Out:
#      Source Name Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# 0       Sample 1          ERS2709526          SAMEA4890530
# 1       Sample 1          ERS2709526          SAMEA4890530
# 2       Sample 1          ERS2709526          SAMEA4890530
# 3       Sample 1          ERS2709526          SAMEA4890530
# 4       Sample 1          ERS2709526          SAMEA4890530
# ...          ...                 ...                   ...
# 2555   Sample 10          ERS2709529          SAMEA4890533
# 2556   Sample 10          ERS2709529          SAMEA4890533
# 2557   Sample 10          ERS2709529          SAMEA4890533
# 2558   Sample 10          ERS2709529          SAMEA4890533
# 2559   Sample 10          ERS2709529          SAMEA4890533
#
#      Characteristics[organism] Characteristics[strain]  \
# 0                 Mus musculus                C57BL/6J
# 1                 Mus musculus                C57BL/6J
# 2                 Mus musculus                C57BL/6J
# 3                 Mus musculus                C57BL/6J
# 4                 Mus musculus                C57BL/6J
# ...                        ...                     ...
# 2555              Mus musculus                C57BL/6J
# 2556              Mus musculus                C57BL/6J
# 2557              Mus musculus                C57BL/6J
# 2558              Mus musculus                C57BL/6J
# 2559              Mus musculus                C57BL/6J
#
#      Characteristics[developmental stage] Characteristics[individual]  \
# 0                       embryonic day 6.5               embryo pool 1
# 1                       embryonic day 6.5               embryo pool 1
# 2                       embryonic day 6.5               embryo pool 1
# 3                       embryonic day 6.5               embryo pool 1
# 4                       embryonic day 6.5               embryo pool 1
# ...                                   ...                         ...
# 2555                    embryonic day 7.0               embryo pool 9
# 2556                    embryonic day 7.0               embryo pool 9
# 2557                    embryonic day 7.0               embryo pool 9
# 2558                    embryonic day 7.0               embryo pool 9
# 2559                    embryonic day 7.0               embryo pool 9
#
#      Characteristics[organism part] Characteristics[genotype]  \
# 0                    whole organism        wild type genotype
# 1                    whole organism        wild type genotype
# 2                    whole organism        wild type genotype
# 3                    whole organism        wild type genotype
# 4                    whole organism        wild type genotype
# ...                             ...                       ...
# 2555                 whole organism        wild type genotype
# 2556                 whole organism        wild type genotype
# 2557                 whole organism        wild type genotype
# 2558                 whole organism        wild type genotype
# 2559                 whole organism        wild type genotype
#
#      Characteristics[sex]  ...                        Comment[read2 file]  \
# 0                   mixed  ...   22089_1_AAACGGCG_S1_L001_R3_001.fastq.gz
# 1                   mixed  ...   22089_1_CCTACCAT_S2_L001_R3_001.fastq.gz
# 2                   mixed  ...   22089_1_GGCGTTTC_S3_L001_R3_001.fastq.gz
# 3                   mixed  ...   22089_1_TTGTAAGA_S4_L001_R3_001.fastq.gz
# 4                   mixed  ...  22089_2_AAACGGCG_S45_L002_R3_001.fastq.gz
# ...                   ...  ...                                        ...
# 2555                mixed  ...  22111_1_TTTCGCGA_S40_L001_R3_001.fastq.gz
# 2556                mixed  ...  22111_2_ACAGCAAC_S81_L002_R3_001.fastq.gz
# 2557                mixed  ...  22111_2_CGCAATTT_S82_L002_R3_001.fastq.gz
# 2558                mixed  ...  22111_2_GAGTTGCG_S83_L002_R3_001.fastq.gz
# 2559                mixed  ...  22111_2_TTTCGCGA_S84_L002_R3_001.fastq.gz
#
#                                    Comment[FASTQ_URI].1  \
# 0     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 1     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 3     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 4     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                 ...
# 2555  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2556  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2557  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2558  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2559  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                            Comment[index1 file]  \
# 0      22089_1_AAACGGCG_S1_L001_R2_001.fastq.gz
# 1      22089_1_CCTACCAT_S2_L001_R2_001.fastq.gz
# 2      22089_1_GGCGTTTC_S3_L001_R2_001.fastq.gz
# 3      22089_1_TTGTAAGA_S4_L001_R2_001.fastq.gz
# 4     22089_2_AAACGGCG_S45_L002_R2_001.fastq.gz
# ...                                         ...
# 2555  22111_1_TTTCGCGA_S40_L001_R2_001.fastq.gz
# 2556  22111_2_ACAGCAAC_S81_L002_R2_001.fastq.gz
# 2557  22111_2_CGCAATTT_S82_L002_R2_001.fastq.gz
# 2558  22111_2_GAGTTGCG_S83_L002_R2_001.fastq.gz
# 2559  22111_2_TTTCGCGA_S84_L002_R2_001.fastq.gz
#
#                                    Comment[FASTQ_URI].2  \
# 0     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 1     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 3     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 4     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                 ...
# 2555  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2556  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2557  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2558  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2559  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                            Comment[index2 file]  \
# 0      22089_1_AAACGGCG_S1_L001_I1_001.fastq.gz
# 1      22089_1_CCTACCAT_S2_L001_I1_001.fastq.gz
# 2      22089_1_GGCGTTTC_S3_L001_I1_001.fastq.gz
# 3      22089_1_TTGTAAGA_S4_L001_I1_001.fastq.gz
# 4     22089_2_AAACGGCG_S45_L002_I1_001.fastq.gz
# ...                                         ...
# 2555  22111_1_TTTCGCGA_S40_L001_I1_001.fastq.gz
# 2556  22111_2_ACAGCAAC_S81_L002_I1_001.fastq.gz
# 2557  22111_2_CGCAATTT_S82_L002_I1_001.fastq.gz
# 2558  22111_2_GAGTTGCG_S83_L002_I1_001.fastq.gz
# 2559  22111_2_TTTCGCGA_S84_L002_I1_001.fastq.gz
#
#                                    Comment[FASTQ_URI].3 Protocol REF.4  \
# 0     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 1     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 2     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 3     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 4     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# ...                                                 ...            ...
# 2555  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 2556  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 2557  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 2558  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
# 2559  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...   P-MTAB-81281
#
#      Derived Array Data File  \
# 0          atlas_data.tar.gz
# 1          atlas_data.tar.gz
# 2          atlas_data.tar.gz
# 3          atlas_data.tar.gz
# 4          atlas_data.tar.gz
# ...                      ...
# 2555       atlas_data.tar.gz
# 2556       atlas_data.tar.gz
# 2557       atlas_data.tar.gz
# 2558       atlas_data.tar.gz
# 2559       atlas_data.tar.gz
#
#                 Comment [Derived ArrayExpress FTP file]  \
# 0     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 1     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 3     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 4     ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                 ...
# 2555  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2556  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2557  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2558  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 2559  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#      Factor Value[developmental stage]
# 0                    embryonic day 6.5
# 1                    embryonic day 6.5
# 2                    embryonic day 6.5
# 3                    embryonic day 6.5
# 4                    embryonic day 6.5
# ...                                ...
# 2555                 embryonic day 7.0
# 2556                 embryonic day 7.0
# 2557                 embryonic day 7.0
# 2558                 embryonic day 7.0
# 2559                 embryonic day 7.0
#
# [2560 rows x 64 columns]

# %%
names = met['Assay Name'].to_list()
names[0:5]
# Out:
# ['22089_1_AAACGGCG_S1_L001',
#  '22089_1_CCTACCAT_S2_L001',
#  '22089_1_GGCGTTTC_S3_L001',
#  '22089_1_TTGTAAGA_S4_L001',
#  '22089_2_AAACGGCG_S45_L002']

# %% [markdown]
# ### Create folders to store files acoording to e_stage

# %%
stages=['E_6.5','E_6.75','E_7.0','E_7.25','E_7.5','E_7.75','E_8.0','E-8.26','E_8.5', 'mixed']

# %%
for stage in stages:
    os.mkdir(path_to_files + stage)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/jobs/ppascual/19149137/ipykernel_13669/3856771825.py in <module>
#       1 for stage in stages:
# ----> 2     os.mkdir(path_to_files + stage)
#
# FileExistsError: [Errno 17] File exists: '/homes/users/ppascual/scratch/STAR_Align/Data/Reads/Pijuan/E_6.5'

# %%
#classifying each file to the corresponding directory according to embryonic stage
for filename in onlyfiles:
    for assay in names:
        if filename.startswith(assay):
            stage = met.loc[met['Assay Name'] == assay, 'Characteristics[developmental stage]'].item()
        
            if stage == 'embryonic day 6.5':
                    os.replace(path_to_files + filename, path_to_files + "E_6.5/" + filename)
            elif stage == 'embryonic day 6.75':
                    os.replace(path_to_files + filename, path_to_files + "E_6.75/" + filename)
            elif stage == 'embryonic day 7.0':
                    os.replace(path_to_files + filename, path_to_files + "E_7.0/" + filename)
            elif stage == 'embryonic day 7.25':
                    os.replace(path_to_files + filename, path_to_files + "E_7.25/" + filename)
            elif stage == 'embryonic day 7.5':
                    os.replace(path_to_files + filename, path_to_files + "E_7.5/" + filename)
            elif stage == 'embryonic day 7.75':
                    os.replace(path_to_files + filename, path_to_files + "E_7.75/" + filename)
            elif stage == 'embryonic day 8.0':
                    os.replace(path_to_files + filename, path_to_files + "E_8.0/" + filename)
            elif stage == 'embryonic day 8.25':
                    os.replace(path_to_files + filename, path_to_files + "E_8.25/" + filename)
            elif stage == 'embryonic day 8.5':
                    os.replace(path_to_files + filename, path_to_files + "E_8.5/" + filename)
            elif stage == 'mixed':
                    os.replace(path_to_files + filename, path_to_files + "mixed" + filename)
